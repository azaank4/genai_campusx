# %% [markdown]
# Duck Duck Go search tool

# %%
from langchain_community.tools import DuckDuckGoSearchRun

search_tool = DuckDuckGoSearchRun()

results = search_tool.invoke('which is koenigseggs fasterst car?')
print(results)
# Out:
# The fastest road-legal car you can officially buy in the UK is the Koenigsegg Jesko Absolut, a bonkers Swedish supercar with a 5.0-litre V8, 1,600hp and a theoretical top speed of over 310mph. The fastest cars in the world come from Hennessey, Bugatti, Koenigsegg , SSC, and Devel, with a top speed of 347 mph (550km/h). May 8, 2025 Koenigsegg's Hypercar Just Set Two More Bonkers Speed Records The Jesko Absolut is now the fastest production car in the standing half-mile and fastest gas car in the quarter-mile. The Koenigsegg Jesko is among the quickest production cars of all time, and during some recent testing at the Swedish automaker's headquarters, has set a new top speed world record for a ... Discover the Koenigsegg Jesko Absolut, the world's fastest production car in 2025, reaching a top speed of 330 mph.

# %% [markdown]
# Shell Tool

# %%
from langchain_community.tools import ShellTool

shell_tool = ShellTool()

results = shell_tool.invoke('npm -v')
print(results)
# Out:
# Executing command:
#  npm -v
# 11.2.0
